# %% [markdown]
# # Looking at downloading the publically avilable ftp datasets from ECMWF

# %% [markdown]
# **Created:** Leo Peach
#
# **Purpose:** Downloading files from the ECMWF ftp data servers

# %%
from ftplib import FTP

# %% [markdown]
# Inside the corporate proxy we need to send the request to the proxy and then include where we really want to go in the username.

# %%
#ftp proxy required for work
#site = FTP("gw-ftp.dmz")
#msg = site.login('wmo@dissemination.ecmwf.int', 'essential')
site = FTP("dissemination.ecmwf.int")
msg = site.login('wmo', 'essential')

# %% [markdown]
# Now lets use the connect to get a list of folders on the highest level

# %%
files = []

try:
    files = site.nlst()
except ftplib.error_perm:
    if str(resp) == "550 No files found":
        print("No files in this directory")
    else:
        raise

#ite.cwd('/20190206000000')
#site.retrlines('LIST')
#dataList = site.dir()

# %% [markdown]
# fortunately the server provides the folders in date order, we can use the last date to change the directory and go into the latest available forecasts

# %%
site.cwd("/"+files[-1])
# Out:
# '250 CWD command successful'

# %% [markdown]
# now grab a new file list

# %%
files = []

try:
    files = site.nlst()
except ftplib.error_perm:
    if str(resp) == "550 No files found":
        print("No files in this directory")
    else:
        raise
#site.close()

# %%
files[0:10]
# Out:
# ['A_HVXA85ECMF070000_C_ECMF_20190207000000_an_v_850hPa_global_0p5deg_grib2.bin',
#  'A_HUXA85ECMF070000_C_ECMF_20190207000000_an_u_850hPa_global_0p5deg_grib2.bin',
#  'A_HTXA85ECMF070000_C_ECMF_20190207000000_an_t_850hPa_global_0p5deg_grib2.bin',
#  'A_HPXA89ECMF070000_C_ECMF_20190207000000_an_msl_global_0p5deg_grib2.bin',
#  'A_HHXA50ECMF070000_C_ECMF_20190207000000_an_gh_500hPa_global_0p5deg_grib2.bin',
#  'A_HVXE85ECMF070000_C_ECMF_20190207000000_24h_v_850hPa_global_0p5deg_grib2.bin',
#  'A_HUXE85ECMF070000_C_ECMF_20190207000000_24h_u_850hPa_global_0p5deg_grib2.bin',
#  'A_HTXE85ECMF070000_C_ECMF_20190207000000_24h_t_850hPa_global_0p5deg_grib2.bin',
#  'A_HPXE89ECMF070000_C_ECMF_20190207000000_24h_msl_global_0p5deg_grib2.bin',
#  'A_HHXE50ECMF070000_C_ECMF_20190207000000_24h_gh_500hPa_global_0p5deg_grib2.bin']

# %% [markdown]
# There are tonnes of files lets for now choose the msl pressure one, the ecmwf website helps with working out what is what (https://www.ecmwf.int/en/forecasts/datasets/wmo-essential), we will look at mean sea level pressure for now.

# %%
msl_files = []
for file in files:
    if 'msl' in file:
        if 'em' in file:
            continue
        if 'es' in file:
            continue
        msl_files.append(file)
msl_files
# Out:
# ['A_HPXA89ECMF070000_C_ECMF_20190207000000_an_msl_global_0p5deg_grib2.bin',
#  'A_HPXE89ECMF070000_C_ECMF_20190207000000_24h_msl_global_0p5deg_grib2.bin',
#  'A_HPXI89ECMF070000_C_ECMF_20190207000000_48h_msl_global_0p5deg_grib2.bin',
#  'A_HPXK89ECMF070000_C_ECMF_20190207000000_72h_msl_global_0p5deg_grib2.bin',
#  'A_HPXM89ECMF070000_C_ECMF_20190207000000_96h_msl_global_0p5deg_grib2.bin',
#  'A_HPXO89ECMF070000_C_ECMF_20190207000000_120h_msl_global_0p5deg_grib2.bin',
#  'A_HPXQ89ECMF070000_C_ECMF_20190207000000_144h_msl_global_0p5deg_grib2.bin',
#  'A_HPXS89ECMF070000_C_ECMF_20190207000000_168h_msl_global_0p5deg_grib2.bin',
#  'A_HPXW89ECMF070000_C_ECMF_20190207000000_192h_msl_global_0p5deg_grib2.bin',
#  'A_HPXY89ECMF070000_C_ECMF_20190207000000_216h_msl_global_0p5deg_grib2.bin',
#  'A_HPXT89ECMF070000_C_ECMF_20190207000000_240h_msl_global_0p5deg_grib2.bin']

# %%
filename = msl_files[0]

localfile = open(filename, 'wb')
try:
    site.retrbinary('RETR ' + filename, localfile.write, 1024)
except:
    print("Error")
localfile.close()


#write file to memory
import io
bio = io.BytesIO()

resp = site.retrbinary('RETR '+msl_files[0], bio.write,1024)
bio.seek(0) # Go back to the start

site.quit()
localfile.close()

# %% [markdown]
# Now we need to read in that file and convert it to something we can use

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('/home/leo/Documents/Python/ECMWF Projects/A_HPXE89ECMF061200_C_ECMF_20190206120000_24h_msl_global_0p5deg_grib2.grib', engine='cfgrib')

# %%
ds.time.data
# Out:
# numpy.datetime64('2019-02-06T12:00:00.000000000')

# %%
ds.longitude.values.shape
# Out:
# (720,)

# %% [markdown]
# Lets make a plot

# %%
import matplotlib.cm as cm
from mpl_toolkits.basemap import Basemap
import os
import io
import numpy as np


pres_max = 1010.0
pres_min = 990.0
fig, axes = plt.subplots(figsize=(10,8))

lon_0 = ds.longitude.data.mean()
lat_0 = ds.latitude.data.mean()
    
if (ds.msl.values /100).max() > pres_max:
        pres_max = (ds.msl.values /100).max()
if (ds.msl.values /100).min() < pres_max:    
        pres_min = (ds.msl.values /100).min()
    
    
map_ax = Basemap(resolution='l',projection='tmerc', lat_0=lat_0,lon_0=lon_0, llcrnrlon=130, llcrnrlat=-31
               ,urcrnrlon=160, urcrnrlat=-8.0)
lon, lat = np.meshgrid(ds.longitude.data, ds.latitude.data)
xi, yi = map_ax(lon, lat)
map_ax.contour(xi, yi, (ds.msl.values /100), 10, vmin = pres_min, vmax = pres_max, colors="black")
im = map_ax.contourf(xi, yi,(ds.msl.values/100), 10, vmin = pres_min, vmax = pres_max, cmap=plt.get_cmap("jet"))
m = plt.cm.ScalarMappable(cmap=cm.coolwarm)
m.set_array((ds.msl.values /100))
m.set_clim(pres_min, pres_max)
# Add a color bar
cbar = plt.colorbar(im, boundaries=np.arange(pres_min,pres_max,4))
cbar.set_label('Sea Level Pressure (hPa)')
map_ax.drawcoastlines()
map_ax.drawstates()
plt.title(str(ds.time.values)[:-5])
buf = io.BytesIO()
plt.savefig(buf, format='png')
#maps.append(Image.open(buf))
